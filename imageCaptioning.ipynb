# %% [markdown]
# ## Use this sub-section for downloading complete dataset

# %%
cd /content

# %%
# !wget https://github.com/jbrownlee/Datasets/releases/download/Flickr8k/Flickr8k_Dataset.zip
# !wget https://github.com/jbrownlee/Datasets/releases/download/Flickr8k/Flickr8k_text.zip
# !unzip -qq Flickr8k_Dataset.zip -d all_images
# !unzip -qq Flickr8k_text.zip -d all_captions

# %%
mv all_images flickr8k

# %%
cd flickr8k

# %%
mv Flicker8k_Dataset images

# %%
cd '/content/drive/My Drive/imageCaptioning/training'
# Out:
# /content/drive/My Drive/imageCaptioning/training

# %% [markdown]
# ## Print GPU statistics

# %%
# !nvidia-smi
# Out:
# Sun Aug  9 16:01:08 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 450.57       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   34C    P8     9W /  70W |      0MiB / 15079MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %% [markdown]
# ## Train

# %%
# !python train.py
# Out:
# Example 1 CORRECT: Dog on a beach by the ocean
# Example 1 OUTPUT: drenched drenched drenched drenched drenched craft craft cards cards cards cards cards cards cards cards cards ambulance ambulance ambulance ambulance drenched drenched drenched drenched drenched drenched craft craft cards cards cards cards cards cards cards cards cards ambulance ambulance ambulance ambulance drenched drenched drenched drenched drenched drenched craft craft cards
# Example 2 CORRECT: Child holding red frisbee outdoors
# Example 2 OUTPUT: drenched drenched drenched drenched drenched craft craft cards cards cards cards cards cards cards cards ambulance ambulance ambulance ambulance drenched drenched drenched drenched drenched drenched craft craft cards cards cards cards cards cards cards cards cards ambulance ambulance ambulance ambulance drenched drenched drenched drenched drenched drenched craft craft cards cards
# Example 3 CORRECT: Bus driving by parked cars
# ...
